# %%
import pandas as pd

# %% [markdown]
# # Data Cleaning
#
# ## Overview
# The purpose of this data cleaning step is to prepare the raw dataset for analysis and modeling by standardizing missing values, ensuring consistency, and preserving the original raw data.
#
# ---
#
# ## Data Loading
# The raw dataset is loaded from the `data/raw` directory. During loading, placeholder values representing missing data are automatically converted to `NaN`.

# %%
import sys
import os

# Get absolute path to src folder from notebook location
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))
print("Adding to sys.path:", src_path)
 
# Add src to Python path
if src_path not in sys.path:
    sys.path.append(src_path)

# Now import your cleaning function
from data_cleaning import clean_diabetic_data

# Run the cleaning pipeline
cleaned_df = clean_diabetic_data()

# Inspect the first few rows
cleaned_df.head()
# Out:
# Adding to sys.path: c:\Charuka Dev Projects\Python Final Project\src
# c:\Charuka Dev Projects\Python Final Project\src\data_cleaning.py:15: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, na_values=["?"])
# Loaded data with shape: (101766, 50)
# Dropping columns due to missing values > 90.0%: ['weight']
# Removed 1642 expired patients.
# Merged descriptions for 'discharge_disposition_id' into 'discharge_desc' column.
# Merged descriptions for 'admission_type_id' into 'admission_type_desc' column.
# Merged descriptions for 'admission_source_id' into 'admission_source_desc' column.
# Removed 0 duplicate rows.
